# %% [markdown]
# <a href="https://colab.research.google.com/github/AmeerAlkhier/Misc/blob/main/A_Copy_of_BERN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! ls
# Out:
# drive  sample_data

# %%
# remove a folder 
# !rm -rf sample_data
! ls
# Out:
# drive

# %%
# %cd ..
# Out:
# /

# %%
! ls
# Out:
# bin	 datalab  home	 lib64	opt	    root  srv		     tmp    var
# boot	 dev	  lib	 media	proc	    run   sys		     tools
# content  etc	  lib32  mnt	python-apt  sbin  tensorflow-1.15.2  usr

# %%
# %cd /content/bern_project
# Out:
# /content/bern_project

# %%
! git clone https://github.com/dmis-lab/bern.git # !sign was missing produced syntax error
# Out:
# Cloning into 'bern'...
# remote: Enumerating objects: 222, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 222 (delta 7), reused 7 (delta 3), pack-reused 203
# Receiving objects: 100% (222/222), 1012.16 KiB | 7.85 MiB/s, done.
# Resolving deltas: 100% (124/124), done.

# %%
# %cd /content/bern_project/bern/
! ls
# Out:
# /content/bern_project/bern
# bern_overview.jpg  __init__.py	  normalizers	    server.py
# biobert_ner	   LICENSE	  README.md	    service_checker.py
# convert.py	   load_dicts.sh  requirements.txt  stop_normalizers.sh
# download.py	   normalize.py   scripts	    utils.py

# %%
! pip3 install -r requirements.txt --user
# Out:
# ...
#      |████████████████████████████████| 458.3 MB 10 kB/s
# ...
#   WARNING: The scripts estimator_ckpt_converter, import_pb_to_tensorboard, saved_model_cli, tensorboard, tf_upgrade_v2, tflite_convert, toco and toco_from_protos are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
# %cd ~/bern 
# this caused an error

# %%
! pwd
# Out:
# /content/bern_project/bern

# %%
! wget https://www.ncbi.nlm.nih.gov/CBBresearch/Lu/Demo/tmTools/download/GNormPlus/GNormPlusJava.zip
! unzip GNormPlusJava.zip
# Out:
# --2021-09-19 12:12:28--  https://www.ncbi.nlm.nih.gov/CBBresearch/Lu/Demo/tmTools/download/GNormPlus/GNormPlusJava.zip
# Resolving www.ncbi.nlm.nih.gov (www.ncbi.nlm.nih.gov)... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to www.ncbi.nlm.nih.gov (www.ncbi.nlm.nih.gov)|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 775574870 (740M) [application/zip]
# Saving to: ‘GNormPlusJava.zip’
#
# GNormPlusJava.zip   100%[===================>] 739.65M  1.65MB/s    in 6m 6s
#
# 2021-09-19 12:18:34 (2.02 MB/s) - ‘GNormPlusJava.zip’ saved [775574870/775574870]
#
# Archive:  GNormPlusJava.zip
#    creating: GNormPlusJava/
#   inflating: GNormPlusJava/Ab3P
#    creating: GNormPlusJava/bin/
#    creating: GNormPlusJava/bin/GNormPluslib/
#   inflating: GNormPlusJava/bin/GNormPluslib/BioCDoc.class
#   inflating: GNormPlusJava/bin/GNormPluslib/GN.class
#   inflating: GNormPlusJava/bin/GNormPluslib/GNormPlus.class
# ...

# %% [markdown]
# #**pay attention to remove zip files after each download to save space**

# %%
# pay attention to remove zip files after each download to save space
# !rm -rf GNormPlusJava.zip

# %%
# !pwd
! ls
# Out:
# /content/bern_project/bern
# bern_overview.jpg  __init__.py	  README.md	      stop_normalizers.sh
# biobert_ner	   LICENSE	  requirements.txt    utils.py
# convert.py	   load_dicts.sh  scripts
# download.py	   normalize.py   server.py
# GNormPlusJava	   normalizers	  service_checker.py

# %%
# %cd /content/bern_project/bern/GNormPlusJava
# Out:
# /content/bern_project/bern/GNormPlusJava

# %%
# !wget -O ./crfpp-0.58.tar.gz https://drive.google.com/uc?id=0B4y35FiV1wh7QVR6VXJ5dWExSTQ
# Out:
# --2021-09-19 12:43:24--  https://drive.google.com/uc?id=0B4y35FiV1wh7QVR6VXJ5dWExSTQ
# Resolving drive.google.com (drive.google.com)... 108.177.111.102, 108.177.111.113, 108.177.111.138, ...
# Connecting to drive.google.com (drive.google.com)|108.177.111.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-08-74-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/q9m220ed056l3tikosakh425g3h1q061/1632055350000/13553212398903315502/*/0B4y35FiV1wh7QVR6VXJ5dWExSTQ [following]
# ...
# --2021-09-19 12:43:31--  https://doc-08-74-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/q9m220ed056l3tikosakh425g3h1q061/1632055350000/13553212398903315502/*/0B4y35FiV1wh7QVR6VXJ5dWExSTQ
# Resolving doc-08-74-docs.googleusercontent.com (doc-08-74-docs.googleusercontent.com)... 209.85.145.132, 2607:f8b0:4001:c1e::84
# ...

# %%
# !tar xvfz crfpp-0.58.tar.gz
# !cp -rf CRF++-0.58/* CRF
# Out:
# CRF++-0.58/
# CRF++-0.58/INSTALL
# CRF++-0.58/python/
# CRF++-0.58/python/test.py
# CRF++-0.58/python/README
# CRF++-0.58/python/CRFPP.py
# CRF++-0.58/python/setup.py
# CRF++-0.58/python/CRFPP_wrap.cxx
# CRF++-0.58/Makefile.in
# CRF++-0.58/encoder.cpp
# CRF++-0.58/node.h
# CRF++-0.58/param.cpp
# CRF++-0.58/swig/
# CRF++-0.58/swig/CRFPP_wrap.c
# CRF++-0.58/swig/version.h
# CRF++-0.58/swig/version.h.in
# CRF++-0.58/swig/Makefile
# CRF++-0.58/swig/CRFPP.i
# CRF++-0.58/config.h.in
# CRF++-0.58/feature_cache.cpp
# CRF++-0.58/config.guess
# CRF++-0.58/scoped_ptr.h
# CRF++-0.58/node.cpp
# CRF++-0.58/README
# CRF++-0.58/timer.h
# CRF++-0.58/feature_index.h
# CRF++-0.58/config.sub
# CRF++-0.58/ltmain.sh
# CRF++-0.58/common.h
# CRF++-0.58/configure
# CRF++-0.58/crf_learn.cpp
# CRF++-0.58/darts.h
# CRF++-0.58/winmain.h
# CRF++-0.58/doc/
# CRF++-0.58/doc/html/
# CRF++-0.58/doc/html/search/
# CRF++-0.58/doc/html/search/nomatches.html
# CRF++-0.58/doc/html/search/search_r.png
# ...

# %%
# %cd CRF
# !sh ./configure
# !make
# !sudo make install
# Out:
# /content/bern_project/bern/GNormPlusJava/CRF
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking for style of include used by make... GNU
# checking dependency style of gcc... gcc3
# checking for g++... g++
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# ...

# %%
# %cd ..
# !chmod 764 Ab3P
# chmod 764 CRF/crf_test
# !pwd
# Out:
# /content/bern_project/bern/GNormPlusJava
# /content/bern_project/bern/GNormPlusJava

# %%
# Set FocusSpecies to 9606 (Human)
# !sed -i 's/= All/= 9606/g' setup.txt; echo "FocusSpecies: from All to 9606 (Human)"
# !sh Installation.sh

# !rm -r CRF++-0.58
# !rm crfpp-0.58.tar.gz
# Out:
# FocusSpecies: from All to 9606 (Human)
# rm CRF/crf_test
# rm CRF/crf_test.o
# cd CRF
# make crf_test;
# g++ -DHAVE_CONFIG_H -I.     -O3 -Wall -c -o crf_test.o crf_test.cpp
# /bin/bash ./libtool --tag=CXX   --mode=link g++  -O3 -Wall   -o crf_test crf_test.o libcrfpp.la  -lpthread -lpthread -lm -lm -lm
# libtool: link: g++ -O3 -Wall -o .libs/crf_test crf_test.o  ./.libs/libcrfpp.so -lpthread -lm
# cd ..
# done

# %%
# Download GNormPlusServer.jar
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1g-JlhqeDIlZX5YFk8Y27_M8BXUXcQRSX' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1g-JlhqeDIlZX5YFk8Y27_M8BXUXcQRSX" -O GNormPlusServer.jar && rm -rf /tmp/cookies.txt
#logs folder created manually AND THE ROOT SIGN CAUSED AN ERROR
# Start GNormPlusServer
# !nohup java -Xmx16G -Xms16G -jar GNormPlusServer.jar 18895 >> /content/bern_project/bern/logs/nohup_gnormplus.out 2>&1 &
# Out:
# --2021-09-19 12:48:19--  https://docs.google.com/uc?export=download&confirm=&id=1g-JlhqeDIlZX5YFk8Y27_M8BXUXcQRSX
# Resolving docs.google.com (docs.google.com)... 142.250.148.102, 142.250.148.139, 142.250.148.100, ...
# Connecting to docs.google.com (docs.google.com)|142.250.148.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0k-3s-docs.googleusercontent.com/docs/securesc/an087l66gkq1k30lc5pgtkv5penk0gd4/7asjgvrog1pil2kdhk7h4k9ibrkahpnq/1632055650000/06985761307889573270/14889058481434828511Z/1g-JlhqeDIlZX5YFk8Y27_M8BXUXcQRSX?e=download [following]
# --2021-09-19 12:48:29--  https://doc-0k-3s-docs.googleusercontent.com/docs/securesc/an087l66gkq1k30lc5pgtkv5penk0gd4/7asjgvrog1pil2kdhk7h4k9ibrkahpnq/1632055650000/06985761307889573270/14889058481434828511Z/1g-JlhqeDIlZX5YFk8Y27_M8BXUXcQRSX?e=download
# ...

# %%
# %cd /content/bern_project/bern/
! pwd
# Out:
# /content/bern_project/bern
# /content/bern_project/bern

# %%
# !wget ftp://ftp.ncbi.nlm.nih.gov/pub/lu/Suppl/tmVar2/tmVarJava.zip
# Out:
# --2021-09-19 12:48:48--  ftp://ftp.ncbi.nlm.nih.gov/pub/lu/Suppl/tmVar2/tmVarJava.zip
#            => ‘tmVarJava.zip’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 165.112.9.228, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/lu/Suppl/tmVar2 ... done.
# ==> SIZE tmVarJava.zip ... 17394517309
# ==> PASV ... done.    ==> RETR tmVarJava.zip ... done.
# Length: 17394517309 (16G) (unauthoritative)
#
# tmVarJava.zip       100%[===================>]  16.20G  55.8MB/s    in 5m 35s
#
# 2021-09-19 12:54:24 (49.5 MB/s) - ‘tmVarJava.zip’ saved [17394517309]

# %%
# !unzip tmVarJava.zip
# Out:
# Archive:  tmVarJava.zip
#    creating: tmVarJava/
#    creating: tmVarJava/bin/
#   inflating: tmVarJava/bin/bioc.jar
#   inflating: tmVarJava/bin/commons-lang-2.4.jar
#   inflating: tmVarJava/bin/filtering.txt
#   inflating: tmVarJava/bin/j-seqalign.jar
#   inflating: tmVarJava/bin/mallet-deps.jar
#   inflating: tmVarJava/bin/mallet.jar
#   inflating: tmVarJava/bin/org.tartarus.snowball.jar
#   inflating: tmVarJava/bin/pengyifan-pubtator-0.0.3-SNAPSHOT-jar-with-dependencies.jar
#    creating: tmVarJava/bin/RegEx/
#   inflating: tmVarJava/bin/RegEx/DNAMutation.RegEx.txt
#   inflating: tmVarJava/bin/RegEx/MF.RegEx.2.txt
#   inflating: tmVarJava/bin/RegEx/ProteinMutation.RegEx.txt
#    creating: tmVarJava/bin/RegEx/RegEx.MF/
#   inflating: tmVarJava/bin/RegEx/RegEx.MF/MFsub.txt
#   inflating: tmVarJava/bin/RegEx/SNP.RegEx.txt
#   inflating: tmVarJava/bin/RegEx/SplitComponent.txt
#   inflating: tmVarJava/bin/sptoolkit.jar
#   inflating: tmVarJava/bin/stanford-postagger-3.5.2.jar
# ...

# %%
# remove a zip file 
# !rm -rf tmVarJava.zip

# %%
# running out of disk space problem solved by changing the runtime type
# %cd tmVarJava
# Out:
# /content/bern_project/bern/tmVarJava

# %%
# !wget -O ./crfpp-0.58.tar.gz https://drive.google.com/uc?id=0B4y35FiV1wh7QVR6VXJ5dWExSTQ
# !tar xvfz crfpp-0.58.tar.gz
# !cp -rf CRF++-0.58/* CRF
# Out:
# --2021-09-19 13:17:45--  https://drive.google.com/uc?id=0B4y35FiV1wh7QVR6VXJ5dWExSTQ
# Resolving drive.google.com (drive.google.com)... 108.177.111.101, 108.177.111.100, 108.177.111.102, ...
# Connecting to drive.google.com (drive.google.com)|108.177.111.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-08-74-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/t31n6ipnmmmocm8kt3tahvs9efpfe6ne/1632057450000/13553212398903315502/*/0B4y35FiV1wh7QVR6VXJ5dWExSTQ [following]
# ...
# --2021-09-19 13:17:54--  https://doc-08-74-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/t31n6ipnmmmocm8kt3tahvs9efpfe6ne/1632057450000/13553212398903315502/*/0B4y35FiV1wh7QVR6VXJ5dWExSTQ
# Resolving doc-08-74-docs.googleusercontent.com (doc-08-74-docs.googleusercontent.com)... 209.85.145.132, 2607:f8b0:4001:c1e::84
# ...

# %%
#from google.colab import drive
#drive.mount('/content/drive')
#drive.flush_and_unmount
# sometimes you need to unmount and mount again error code 107
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pwd
! ls
# Out:
# /content/bern_project/bern/tmVarJava
# bin	  CRF		     DISCLAIMER       lib	  tmBioC.key
# BioC.dtd  CRF++-0.58	     input	      output	  tmp
# COPYING   crfpp-0.58.tar.gz  input_GN	      readme.txt  tmVar.jar
# corpus	  Database	     Installation.sh  src	  tmVar.sh

# %%
# %cd  /content/bern_project/bern/tmVarJava
# Out:
# /content/bern_project/bern/tmVarJava

# %%
# %cd CRF
# Out:
# /content/bern_project/bern/tmVarJava/CRF

# %%
# !sh ./configure
# !make
# !sudo make install
# Out:
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking for style of include used by make... GNU
# checking dependency style of gcc... gcc3
# checking for g++... g++
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking dependency style of g++... gcc3
# ...

# %%
# %cd ..
# Out:
# /content/bern_project/bern/tmVarJava

# %%
# !chmod 764 CRF/crf_test

# !sh Installation.sh

# !rm -r CRF++-0.58
# !rm crfpp-0.58.tar.gz
# Out:
# rm CRF/crf_test
# rm CRF/crf_test.o
# cd CRF
# make crf_test;
# g++ -DHAVE_CONFIG_H -I.     -O3 -Wall -c -o crf_test.o crf_test.cpp
# /bin/bash ./libtool --tag=CXX   --mode=link g++  -O3 -Wall   -o crf_test crf_test.o libcrfpp.la  -lpthread -lpthread -lm -lm -lm
# libtool: link: g++ -O3 -Wall -o .libs/crf_test crf_test.o  ./.libs/libcrfpp.so -lpthread -lm
# cd ..
# done

# %%
# Download tmVar2Server.jar
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1kQYzLHLFLsU9qKpRRGjXkIYmaYK6bPJm' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1kQYzLHLFLsU9qKpRRGjXkIYmaYK6bPJm" -O tmVar2Server.jar && rm -rf /tmp/cookies.txt

# Download dependencies
# !wget https://repo1.maven.org/maven2/org/xerial/sqlite-jdbc/3.20.0/sqlite-jdbc-3.20.0.jar
# !wget https://repo1.maven.org/maven2/edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar
# Out:
# --2021-09-19 13:26:44--  https://docs.google.com/uc?export=download&confirm=&id=1kQYzLHLFLsU9qKpRRGjXkIYmaYK6bPJm
# Resolving docs.google.com (docs.google.com)... 142.250.148.113, 142.250.148.101, 142.250.148.138, ...
# Connecting to docs.google.com (docs.google.com)|142.250.148.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0s-50-docs.googleusercontent.com/docs/securesc/g56gvc0vfi0i8i5j3tiiennqh462uqvf/6cpesvtikpc9mde0vgcdj0fdofi3s7pn/1632057975000/06985761307889573270/06276648564151072282Z/1kQYzLHLFLsU9qKpRRGjXkIYmaYK6bPJm?e=download [following]
# --2021-09-19 13:27:05--  https://doc-0s-50-docs.googleusercontent.com/docs/securesc/g56gvc0vfi0i8i5j3tiiennqh462uqvf/6cpesvtikpc9mde0vgcdj0fdofi3s7pn/1632057975000/06985761307889573270/06276648564151072282Z/1kQYzLHLFLsU9qKpRRGjXkIYmaYK6bPJm?e=download
# ...

# %%
# I had to create the folder logs and the file " nohup_tmvar.out " manually 
# review tomcat server  ### this was resolved by removing the root sign 
# !pwd
# Start tmVar2Server
# !nohup java -Xmx8G -Xms8G -jar tmVar2Server.jar 18896 >> /content/bern_project/bern/logs/nohup_tmvar.out 2>&1 &
# Out:
# /content/bern_project/bern

# %% [markdown]
#  Download normalization resources and pre-trained BioBERT NER models

# %%
# %cd /content/bern_project/bern/scripts
# Out:
# /content/bern_project/bern/scripts

# %%
# !pwd
# Out:
# /content/bern_project/bern/scripts

# %%
# !sh download_norm.sh
# !sh download_biobert_ner_models.sh
# Out:
# Not found data.zip. Downloading..
# --2021-09-19 13:36:32--  https://docs.google.com/uc?export=download&confirm=Jk8F&id=1NqgG3zJzopG2IqG-0g1o6fH0xVpO4PPN
# Resolving docs.google.com (docs.google.com)... 142.250.148.139, 142.250.148.101, 142.250.148.138, ...
# Connecting to docs.google.com (docs.google.com)|142.250.148.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0s-5c-docs.googleusercontent.com/docs/securesc/7siomatj4bam5haapj40l97i5opbgmm7/mqbe4u8f8s8gj6mec6npd7eeh0o2j8gl/1632058575000/06985761307889573270/16483873273495479439Z/1NqgG3zJzopG2IqG-0g1o6fH0xVpO4PPN?e=download [following]
# --2021-09-19 13:36:32--  https://doc-0s-5c-docs.googleusercontent.com/docs/securesc/7siomatj4bam5haapj40l97i5opbgmm7/mqbe4u8f8s8gj6mec6npd7eeh0o2j8gl/1632058575000/06985761307889573270/16483873273495479439Z/1NqgG3zJzopG2IqG-0g1o6fH0xVpO4PPN?e=download
# ...

# %%
# remove a zip file 
# maybe don't delete this one yet !rm comentd out
#!rm -rf resources.zip #so youre just above this cell

# %% [markdown]
#    Run named entity normalizers

# %%
# !pwd
# Out:
# /content/bern_project/bern/scripts

# %%
#%cd ..
# %cd /content/bern_project/bern
# Out:
# /content/bern_project/bern

# %%
# !sh load_dicts.sh
# Out:
# root          51  0.2  0.3 198512 52896 ?        Sl   12:06   0:15 /usr/bin/python2 /usr/local/bin/jupyter-notebook --ip="172.28.0.2" --port=9000 --FileContentsManager.root_dir="/" --MappingKernelManager.root_dir="/content"
# root          63  0.7  0.7 726132 95356 ?        Ssl  12:06   0:46 /usr/bin/python3 -m ipykernel_launcher -f /root/.local/share/jupyter/runtime/kernel-8130f5e3-786c-4084-a9f2-dc66db748f14.json
# root          83  0.3  0.0 129176 13140 ?        Sl   12:06   0:18 /usr/bin/python3 /usr/local/lib/python3.7/dist-packages/debugpy/adapter --for-server 35231 --host 127.0.0.1 --port 21200 --server-access-token 5269887315be0ad739f617b0aa30e93270339fe69b40b49d1d931ff75d701075
# root         258  0.0  0.0  18380   432 ?        S    12:07   0:00 bash -c tail -n +0 -F "/root/.config/Google/DriveFS/Logs/drive_fs.txt" | python3 /opt/google/drive/drive-filter.py > "/root/.config/Google/DriveFS/Logs/timeouts.txt"
# ...

# %% [markdown]
# Run BERN server

# %%
# Check your GPU number(s)
output=!echo $CUDA_VISIBLE_DEVICES
output
# Out:
# ['']

# %%
# Set your GPU number(s)
# !export CUDA_VISIBLE_DEVICES=0
# Run BERN
# Please check gnormplus_home directory and tmvar2_home directory.
# !nohup python3 -u server.py --port 8888 --gnormplus_home content/bern_project/bern/GNormPlusJava --gnormplus_port 18895 --tmvar2_home content/bern_project/bern/tmVarJava --tmvar2_port 18896 >> logs/nohup_BERN.out 2>&1 &

# %%
# Print logs
# !tail -F logs/nohup_BERN.out
# Out:
# ^C

# %%
# !curl ipecho.net/plain
# Out:
# 34.66.33.218

# %%
import tensorflow as tf
print(tf. __version__)
# Out:
# 2.6.0
